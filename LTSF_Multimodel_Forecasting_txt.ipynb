# %% [markdown]
# # Time Series Forecasting: Electricity, Traffic, Exchange Rate
# This notebook loads `.txt` datasets and trains Linear, DLinear and NLinear models using PyTorch.

# %%
# Imports
import pandas as pd
import numpy as np
import gzip
import torch
import torch.nn as nn
from sklearn.metrics import mean_squared_error, mean_absolute_error
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import os
import torch
import torch.nn as nn
from torch.nn import TransformerEncoder, TransformerEncoderLayer


device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
# Load plain .txt file
def load_data(filepath):
    return pd.read_csv(filepath, header=None)

# Load all datasets from .txt
datasets = {
    'electricity': load_data('electricity.txt'),
    'traffic': load_data('traffic.txt'),
    'exchange_rate': load_data('exchange_rate.txt')
}

# %%
for name in datasets:
    df = pd.DataFrame(datasets[name])
    datasets[name] = ((df - df.min()) / (df.max() - df.min())).values.astype(np.float32)

# %%
def create_sequences(data, input_len, output_len):
    X, y = [], []
    for i in range(len(data) - input_len - output_len):
        X.append(data[i:i+input_len])
        y.append(data[i+input_len:i+input_len+output_len])
    X = np.array(X)
    y = np.array(y)
    return torch.tensor(X, dtype=torch.float32), torch.tensor(y, dtype=torch.float32)

# %%
import torch
import torch.nn as nn
from torch.nn import TransformerEncoder, TransformerEncoderLayer

# 1. Linear
class LinearModel(nn.Module):
    def __init__(self, input_len, output_len, features):
        super().__init__()
        self.linear = nn.Linear(input_len, output_len)
    def forward(self, x):
        return self.linear(x.transpose(1, 2)).transpose(1, 2)

# 2. DLinear
class DLinear(nn.Module):
    def __init__(self, input_len, output_len, features):
        super().__init__()
        self.decomp = nn.Linear(input_len, input_len)
        self.proj = nn.Linear(input_len, output_len)
    def forward(self, x):
        x = x.transpose(1, 2)
        seasonal = self.decomp(x)
        out = self.proj(seasonal)
        return out.transpose(1, 2)

# 3. NLinear
class NLinear(nn.Module):
    def __init__(self, input_len, output_len, features):
        super().__init__()
        self.norm = nn.LayerNorm(features)
        self.linear = nn.Linear(input_len, output_len)
    def forward(self, x):
        x = self.norm(x)
        return self.linear(x.transpose(1, 2)).transpose(1, 2)

# 4. Transformer (corregido)
class TransformerModel(nn.Module):
    def __init__(self, input_len, output_len, features, d_model=512, nhead=8, num_layers=2):
        super().__init__()
        self.input_proj = nn.Linear(features, d_model)
        encoder_layer = TransformerEncoderLayer(d_model=d_model, nhead=nhead)
        self.transformer = TransformerEncoder(encoder_layer, num_layers=num_layers)
        self.output_proj = nn.Linear(d_model, features)
        self.output_len = output_len

    def forward(self, x):
        # x: [B, L, F]
        x = self.input_proj(x)        # -> [B, L, d_model]
        x = x.transpose(0, 1)         # -> [L, B, d_model]
        x = self.transformer(x)       # -> [L, B, d_model]
        x = x.transpose(0, 1)         # -> [B, L, d_model]
        x = self.output_proj(x)       # -> [B, L, F]

        # Ajustamos para que la salida tenga length = output_len (cortamos o interpolamos)
        if x.shape[1] > self.output_len:
            x = x[:, -self.output_len:, :]  # Cortamos las últimas output_len
        elif x.shape[1] < self.output_len:
            # Upsample temporalmente si es necesario
            x = nn.functional.interpolate(x.transpose(1, 2), size=self.output_len, mode='linear', align_corners=False)
            x = x.transpose(1, 2)

        return x  # [B, output_len, features]


# 5. Autoformer (ya corregido)
class Autoformer(nn.Module):
    def __init__(self, input_len, output_len, features):
        super().__init__()
        self.encoder = nn.Linear(features, features)
        self.decomp = nn.Linear(features, features)
        self.output_proj = nn.Linear(input_len, output_len)
    def forward(self, x):
        trend = self.encoder(x)
        seasonal = x - trend
        seasonal_decomp = self.decomp(seasonal)
        seasonal_decomp = seasonal_decomp.transpose(1, 2)
        out = self.output_proj(seasonal_decomp)
        return out.transpose(1, 2)
class Informer(nn.Module):
    def __init__(self, input_len, output_len, features):
        super().__init__()
        self.input_proj = nn.Linear(features, features)
        self.attn = nn.MultiheadAttention(embed_dim=features, num_heads=1, batch_first=True)
        self.output_proj = nn.Linear(input_len, output_len)  # Proyecta a output_len

    def forward(self, x):
        # x: [B, L, F]
        x = self.input_proj(x)  # [B, L, F]
        attn_output, _ = self.attn(x, x, x)  # [B, L, F]
        attn_output = attn_output.transpose(1, 2)  # [B, F, L]
        out = self.output_proj(attn_output)  # [B, F, output_len]
        return out.transpose(1, 2)  # [B, output_len, F]



# 7. Reformer (corregido)
class Reformer(nn.Module):
    def __init__(self, input_len, output_len, features):
        super().__init__()
        self.linear = nn.Linear(input_len, output_len)
    def forward(self, x):
        return self.linear(x.transpose(1, 2)).transpose(1, 2)

# 8. FEDformer (corregido)
class FEDformer(nn.Module):
    def __init__(self, input_len, output_len, features):
        super().__init__()
        self.filter = nn.Linear(input_len, input_len)
        self.output_proj = nn.Linear(input_len, output_len)
    def forward(self, x):
        freq = torch.fft.rfft(x, dim=1)
        filtered = torch.fft.irfft(freq, n=x.size(1), dim=1)
        filtered = filtered.transpose(1, 2)
        out = self.output_proj(self.filter(filtered))
        return out.transpose(1, 2)

# %%
def train_model(model, X_train, y_train, epochs=10, lr=1e-3, batch_size=64):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()

    dataset = torch.utils.data.TensorDataset(X_train, y_train)
    loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)

    print(f"\n--- Training {model.__class__.__name__} ---")
    print(f"Input shape: {X_train.shape}, Target shape: {y_train.shape}")
    print(f"Device: {device}")

    for epoch in range(epochs):
        model.train()
        epoch_loss = 0.0
        for batch_idx, (x_batch, y_batch) in enumerate(loader):
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)

            optimizer.zero_grad()
            output = model(x_batch)

            if output.shape != y_batch.shape:
                print(f"[!] Shape mismatch at batch {batch_idx}: output {output.shape}, target {y_batch.shape}")
                continue

            loss = loss_fn(output, y_batch)
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()

        print(f"Epoch {epoch+1}/{epochs} | Loss: {epoch_loss:.4f}")

    print(f"Training complete for {model.__class__.__name__} ✅\n")
    return model

# %%
# Evaluation with debug info
def evaluate_model(model, X_test, y_test):
    model.eval()
    print(f"\n--- Evaluating {model.__class__.__name__} ---")
    print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
    
    with torch.no_grad():
        output = model(X_test.to(device))
        pred = output.cpu().numpy()
        true = y_test.cpu().numpy()
    
    print(f"Prediction shape: {pred.shape}, Ground truth shape: {true.shape}")
    
    # Show first few predictions vs true values
    print("\nFirst 5 predictions vs. true values (flattened):")
    for i in range(5):
        print(f"Pred: {pred[i].flatten()[:5]} | True: {true[i].flatten()[:5]}")
    
    mse = mean_squared_error(true.flatten(), pred.flatten())
    mae = mean_absolute_error(true.flatten(), pred.flatten())
    rse = np.sqrt(mse) / np.std(true.flatten())
    corr = np.corrcoef(true.flatten(), pred.flatten())[0, 1]
    
    print(f"\nMetrics:")
    print(f" - MSE:  {mse:.6f}")
    print(f" - MAE:  {mae:.6f}")
    print(f" - RSE:  {rse:.6f}")
    print(f" - Corr: {corr:.6f}")
    
    return mse, mae, rse, corr

# %%
# Run all models on all datasets with debug info
input_len, output_len = 96, 96
results = []

# Lista completa de modelos
model_classes = [LinearModel, DLinear, NLinear, TransformerModel, Autoformer, Informer, Reformer, FEDformer]

for name, data in datasets.items():
    print(f"\n=== Dataset: {name} ===")
    print(f"Original data shape: {data.shape}")

    X, y = create_sequences(data, input_len, output_len)
    print(f"Created sequences -> X: {X.shape}, y: {y.shape}")

    X_train, y_train = X[:500], y[:500]
    X_test, y_test = X[-100:], y[-100:]
    print(f"Train size: {X_train.shape[0]}, Test size: {X_test.shape[0]}")

    for Model in model_classes:
        print(f"\n--- Training model: {Model.__name__} ---")
        model = Model(input_len, output_len, data.shape[1])
        model = train_model(model, X_train, y_train, epochs=10)
        print(f"Finished training {Model.__name__}, now evaluating...")

        mse, mae, rse, corr = evaluate_model(model, X_test, y_test)
        results.append([name, Model.__name__, mse, mae, rse, corr])
# Out:
# === Dataset: electricity ===
# Original data shape: (26304, 321)
# Created sequences -> X: torch.Size([26112, 96, 321]), y: torch.Size([26112, 96, 321])
# Train size: 500, Test size: 100
#
# --- Training model: LinearModel ---
#
# --- Training LinearModel ---
# Input shape: torch.Size([500, 96, 321]), Target shape: torch.Size([500, 96, 321])
# Device: cpu
# Epoch 1/10 | Loss: 1.5277
# Epoch 2/10 | Loss: 0.4801
# Epoch 3/10 | Loss: 0.3108
# Epoch 4/10 | Loss: 0.2766
# Epoch 5/10 | Loss: 0.2386
# Epoch 6/10 | Loss: 0.2036
# Epoch 7/10 | Loss: 0.1837
# Epoch 8/10 | Loss: 0.1688
# Epoch 9/10 | Loss: 0.1557
# Epoch 10/10 | Loss: 0.1448
# Training complete for LinearModel ✅
#
# Finished training LinearModel, now evaluating...
#
# --- Evaluating LinearModel ---
# X_test shape: torch.Size([100, 96, 321]), y_test shape: torch.Size([100, 96, 321])
# Prediction shape: (100, 96, 321), Ground truth shape: (100, 96, 321)
#
# First 5 predictions vs. true values (flattened):
# Pred: [0.13419798 0.3476071  0.07159282 0.7333722  0.7076262 ] | True: [0.08571429 0.35135135 0.01331115 0.85128206 0.68007314]
# Pred: [0.14722693 0.34013575 0.06982233 0.7021501  0.7258642 ] | True: [0.07857143 0.33445945 0.01331115 0.808547   0.7477148 ]
# Pred: [0.13514584 0.32702416 0.07046334 0.7006805  0.7697456 ] | True: [0.08571429 0.3108108  0.01331115 0.7982906  0.72394884]
# Pred: [0.13931888 0.2972405  0.0704546  0.65773237 0.76133573] | True: [0.08571429 0.3006757  0.01331115 0.66068375 0.7605119 ]
# Pred: [0.12779874 0.2900306  0.06845064 0.5909133  0.672392  ] | True: [0.07142857 0.2804054  0.01331115 0.51965815 0.66361976]
#
# Metrics:
#  - MSE:  0.020631
#  - MAE:  0.107505
#  - RSE:  0.749525
#  - Corr: 0.673790
#
# --- Training model: DLinear ---
#
# --- Training DLinear ---
# Input shape: torch.Size([500, 96, 321]), Target shape: torch.Size([500, 96, 321])
# Device: cpu
# Epoch 1/10 | Loss: 1.2196
# Epoch 2/10 | Loss: 0.3549
# Epoch 3/10 | Loss: 0.2537
# Epoch 4/10 | Loss: 0.2071
# Epoch 5/10 | Loss: 0.1720
# Epoch 6/10 | Loss: 0.1490
# Epoch 7/10 | Loss: 0.1303
# Epoch 8/10 | Loss: 0.1156
# Epoch 9/10 | Loss: 0.1044
# Epoch 10/10 | Loss: 0.0959
# Training complete for DLinear ✅
#
# Finished training DLinear, now evaluating...
#
# --- Evaluating DLinear ---
# X_test shape: torch.Size([100, 96, 321]), y_test shape: torch.Size([100, 96, 321])
# Prediction shape: (100, 96, 321), Ground truth shape: (100, 96, 321)
#
# First 5 predictions vs. true values (flattened):
# Pred: [0.16182423 0.3647111  0.10625011 0.70733476 0.68052065] | True: [0.08571429 0.35135135 0.01331115 0.85128206 0.68007314]
# Pred: [0.17226805 0.33395195 0.10625044 0.6813552  0.70853317] | True: [0.07857143 0.33445945 0.01331115 0.808547   0.7477148 ]
# Pred: [0.16874461 0.31693095 0.10557203 0.6437977  0.68298936] | True: [0.08571429 0.3108108  0.01331115 0.7982906  0.72394884]
# Pred: [0.1534555  0.29537725 0.10545036 0.589493   0.6697078 ] | True: [0.08571429 0.3006757  0.01331115 0.66068375 0.7605119 ]
# Pred: [0.15138555 0.27460325 0.10667747 0.5565063  0.6119096 ] | True: [0.07142857 0.2804054  0.01331115 0.51965815 0.66361976]
#
# Metrics:
#  - MSE:  0.015214
#  - MAE:  0.088448
#  - RSE:  0.643646
#  - Corr: 0.766965
#
# --- Training model: NLinear ---
#
# --- Training NLinear ---
# Input shape: torch.Size([500, 96, 321]), Target shape: torch.Size([500, 96, 321])
# Device: cpu
# Epoch 1/10 | Loss: 3.6444
# Epoch 2/10 | Loss: 2.5417
# Epoch 3/10 | Loss: 2.2240
# Epoch 4/10 | Loss: 2.0296
# Epoch 5/10 | Loss: 1.8812
# Epoch 6/10 | Loss: 1.7625
# Epoch 7/10 | Loss: 1.6655
# Epoch 8/10 | Loss: 1.5784
# Epoch 9/10 | Loss: 1.4992
# Epoch 10/10 | Loss: 1.4253
# Training complete for NLinear ✅
#
# Finished training NLinear, now evaluating...
#
# --- Evaluating NLinear ---
# X_test shape: torch.Size([100, 96, 321]), y_test shape: torch.Size([100, 96, 321])
# Prediction shape: (100, 96, 321), Ground truth shape: (100, 96, 321)
#
# First 5 predictions vs. true values (flattened):
# Pred: [-0.44618225 -0.18396083 -0.5290042   0.38899055  0.1915676 ] | True: [0.08571429 0.35135135 0.01331115 0.85128206 0.68007314]
# Pred: [-0.534199   -0.07513101 -0.5226735   0.3767353   0.31840527] | True: [0.07857143 0.33445945 0.01331115 0.808547   0.7477148 ]
# Pred: [-0.4908843  -0.07742844 -0.5085334   0.36765257  0.28765815] | True: [0.08571429 0.3108108  0.01331115 0.7982906  0.72394884]
# Pred: [-0.26000917 -0.06325734 -0.48278862  0.27777162  0.08730774] | True: [0.08571429 0.3006757  0.01331115 0.66068375 0.7605119 ]
# Pred: [-0.4700852  -0.13911143 -0.49344683  0.47135308  0.3904295 ] | True: [0.07142857 0.2804054  0.01331115 0.51965815 0.66361976]
#
# Metrics:
#  - MSE:  0.145017
#  - MAE:  0.328001
#  - RSE:  1.987171
#  - Corr: 0.497542
#
# --- Training model: TransformerModel ---
#
# --- Training TransformerModel ---
# Input shape: torch.Size([500, 96, 321]), Target shape: torch.Size([500, 96, 321])
# Device: cpu
# Epoch 1/10 | Loss: 1.5235
# Epoch 2/10 | Loss: 0.4493
# Epoch 3/10 | Loss: 0.3769
# Epoch 4/10 | Loss: 0.5514
# Epoch 5/10 | Loss: 0.4184
# Epoch 6/10 | Loss: 0.3935
# Epoch 7/10 | Loss: 0.3600
# Epoch 8/10 | Loss: 0.3316
# Epoch 9/10 | Loss: 0.3155
# Epoch 10/10 | Loss: 0.3088
# Training complete for TransformerModel ✅
#
# Finished training TransformerModel, now evaluating...
#
# --- Evaluating TransformerModel ---
# X_test shape: torch.Size([100, 96, 321]), y_test shape: torch.Size([100, 96, 321])
# Prediction shape: (100, 96, 321), Ground truth shape: (100, 96, 321)
#
# First 5 predictions vs. true values (flattened):
# Pred: [0.39300182 0.38105464 0.15686946 0.42253375 0.50564265] | True: [0.08571429 0.35135135 0.01331115 0.85128206 0.68007314]
# Pred: [0.39276436 0.38111094 0.1569257  0.4223891  0.5054429 ] | True: [0.07857143 0.33445945 0.01331115 0.808547   0.7477148 ]
# Pred: [0.3923157  0.38129124 0.15702166 0.42218727 0.5050166 ] | True: [0.08571429 0.3108108  0.01331115 0.7982906  0.72394884]
# Pred: [0.39177716 0.3814776  0.15713592 0.42205703 0.50440234] | True: [0.08571429 0.3006757  0.01331115 0.66068375 0.7605119 ]
# Pred: [0.39122844 0.38149104 0.15705697 0.42186028 0.5038253 ] | True: [0.07142857 0.2804054  0.01331115 0.51965815 0.66361976]
#
# Metrics:
#  - MSE:  0.035068
#  - MAE:  0.148349
#  - RSE:  0.977189
#  - Corr: 0.441792
#
# --- Training model: Autoformer ---
#
# --- Training Autoformer ---
# Input shape: torch.Size([500, 96, 321]), Target shape: torch.Size([500, 96, 321])
# Device: cpu
# Epoch 1/10 | Loss: 1.9680
# Epoch 2/10 | Loss: 0.8549
# Epoch 3/10 | Loss: 0.3743
# Epoch 4/10 | Loss: 0.2504
# Epoch 5/10 | Loss: 0.2176
# Epoch 6/10 | Loss: 0.2020
# Epoch 7/10 | Loss: 0.1874
# Epoch 8/10 | Loss: 0.1717
# Epoch 9/10 | Loss: 0.1550
# Epoch 10/10 | Loss: 0.1376
# Training complete for Autoformer ✅
#
# Finished training Autoformer, now evaluating...
#
# --- Evaluating Autoformer ---
# X_test shape: torch.Size([100, 96, 321]), y_test shape: torch.Size([100, 96, 321])
# Prediction shape: (100, 96, 321), Ground truth shape: (100, 96, 321)
#
# First 5 predictions vs. true values (flattened):
# Pred: [0.1938201  0.20559642 0.05423439 0.43264428 0.5281987 ] | True: [0.08571429 0.35135135 0.01331115 0.85128206 0.68007314]
# Pred: [0.1936953  0.19841397 0.06403606 0.41982195 0.5151214 ] | True: [0.07857143 0.33445945 0.01331115 0.808547   0.7477148 ]
# Pred: [0.1961684  0.18530315 0.10025331 0.39206952 0.49152264] | True: [0.08571429 0.3108108  0.01331115 0.7982906  0.72394884]
# Pred: [0.18787342 0.15644595 0.10445735 0.344685   0.46327093] | True: [0.08571429 0.3006757  0.01331115 0.66068375 0.7605119 ]
# Pred: [0.1356101  0.15816358 0.09888348 0.31516537 0.44752318] | True: [0.07142857 0.2804054  0.01331115 0.51965815 0.66361976]
#
# Metrics:
#  - MSE:  0.031649
#  - MAE:  0.138839
#  - RSE:  0.928334
#  - Corr: 0.476035
#
# --- Training model: Informer ---
#
# --- Training Informer ---
# Input shape: torch.Size([500, 96, 321]), Target shape: torch.Size([500, 96, 321])
# Device: cpu
# Epoch 1/10 | Loss: 1.7643
# Epoch 2/10 | Loss: 0.6700
# Epoch 3/10 | Loss: 0.3216
# Epoch 4/10 | Loss: 0.2434
# Epoch 5/10 | Loss: 0.2175
# Epoch 6/10 | Loss: 0.2107
# Epoch 7/10 | Loss: 0.2075
# Epoch 8/10 | Loss: 0.2066
# Epoch 9/10 | Loss: 0.2055
# Epoch 10/10 | Loss: 0.2051
# Training complete for Informer ✅
#
# Finished training Informer, now evaluating...
#
# --- Evaluating Informer ---
# X_test shape: torch.Size([100, 96, 321]), y_test shape: torch.Size([100, 96, 321])
# Prediction shape: (100, 96, 321), Ground truth shape: (100, 96, 321)
#
# First 5 predictions vs. true values (flattened):
# Pred: [0.37099987 0.37927216 0.16580352 0.37931702 0.4694403 ] | True: [0.08571429 0.35135135 0.01331115 0.85128206 0.68007314]
# Pred: [0.37092674 0.3791661  0.16591397 0.37903526 0.46979058] | True: [0.07857143 0.33445945 0.01331115 0.808547   0.7477148 ]
# Pred: [0.3703524  0.37908903 0.16584462 0.37885612 0.4700402 ] | True: [0.08571429 0.3108108  0.01331115 0.7982906  0.72394884]
# Pred: [0.3701723  0.37932527 0.16571322 0.37916407 0.47128168] | True: [0.08571429 0.3006757  0.01331115 0.66068375 0.7605119 ]
# Pred: [0.37004516 0.37964198 0.16583711 0.37906867 0.47187334] | True: [0.07142857 0.2804054  0.01331115 0.51965815 0.66361976]
# Metrics:
#  - MSE:  0.031938
#  - MAE:  0.145906
#  - RSE:  0.932572
#  - Corr: 0.402984
#
# --- Training model: Reformer ---
#
# --- Training Reformer ---
# Input shape: torch.Size([500, 96, 321]), Target shape: torch.Size([500, 96, 321])
# Device: cpu
# Epoch 1/10 | Loss: 1.5654
# Epoch 2/10 | Loss: 0.5225
# Epoch 3/10 | Loss: 0.3134
# Epoch 4/10 | Loss: 0.2606
# Epoch 5/10 | Loss: 0.2221
# Epoch 6/10 | Loss: 0.1928
# Epoch 7/10 | Loss: 0.1742
# Epoch 8/10 | Loss: 0.1602
# Epoch 9/10 | Loss: 0.1484
# Epoch 10/10 | Loss: 0.1390
# Training complete for Reformer ✅
#
# Finished training Reformer, now evaluating...
#
# --- Evaluating Reformer ---
# X_test shape: torch.Size([100, 96, 321]), y_test shape: torch.Size([100, 96, 321])
# Prediction shape: (100, 96, 321), Ground truth shape: (100, 96, 321)
#
# First 5 predictions vs. true values (flattened):
# Pred: [0.0716575  0.2972717  0.01694185 0.4780666  0.53574705] | True: [0.08571429 0.35135135 0.01331115 0.85128206 0.68007314]
# Pred: [0.05169513 0.27686945 0.01764398 0.475769   0.55101144] | True: [0.07857143 0.33445945 0.01331115 0.808547   0.7477148 ]
# Pred: [0.09498384 0.2652727  0.01596179 0.41442806 0.5594488 ] | True: [0.08571429 0.3108108  0.01331115 0.7982906  0.72394884]
# Pred: [0.09197737 0.2719457  0.01713132 0.46800435 0.5793178 ] | True: [0.08571429 0.3006757  0.01331115 0.66068375 0.7605119 ]
# Pred: [0.08407241 0.2804097  0.01795534 0.46027672 0.6133788 ] | True: [0.07142857 0.2804054  0.01331115 0.51965815 0.66361976]
#
# Metrics:
#  - MSE:  0.020012
#  - MAE:  0.105482
#  - RSE:  0.738192
#  - Corr: 0.683831
#
# --- Training model: FEDformer ---
#
# --- Training FEDformer ---
# Input shape: torch.Size([500, 96, 321]), Target shape: torch.Size([500, 96, 321])
# Device: cpu
# Epoch 1/10 | Loss: 1.2460
# Epoch 2/10 | Loss: 0.3566
# Epoch 3/10 | Loss: 0.2642
# Epoch 4/10 | Loss: 0.2128
# Epoch 5/10 | Loss: 0.1775
# Epoch 6/10 | Loss: 0.1567
# Epoch 7/10 | Loss: 0.1367
# Epoch 8/10 | Loss: 0.1220
# Epoch 9/10 | Loss: 0.1091
# Epoch 10/10 | Loss: 0.0996
# Training complete for FEDformer ✅
#
# Finished training FEDformer, now evaluating...
#
# --- Evaluating FEDformer ---
# X_test shape: torch.Size([100, 96, 321]), y_test shape: torch.Size([100, 96, 321])
# Prediction shape: (100, 96, 321), Ground truth shape: (100, 96, 321)
#
# First 5 predictions vs. true values (flattened):
# Pred: [0.1147887  0.33269736 0.07988597 0.66532665 0.6330356 ] | True: [0.08571429 0.35135135 0.01331115 0.85128206 0.68007314]
# Pred: [0.11326277 0.32994354 0.0787461  0.65656406 0.6305429 ] | True: [0.07857143 0.33445945 0.01331115 0.808547   0.7477148 ]
# Pred: [0.11612809 0.31188387 0.07924666 0.668101   0.6545479 ] | True: [0.08571429 0.3108108  0.01331115 0.7982906  0.72394884]
# Pred: [0.12470539 0.29936352 0.07933259 0.6283564  0.65065724] | True: [0.08571429 0.3006757  0.01331115 0.66068375 0.7605119 ]
# Pred: [0.11532709 0.2853108  0.07806245 0.61127174 0.62151295] | True: [0.07142857 0.2804054  0.01331115 0.51965815 0.66361976]
#
# Metrics:
#  - MSE:  0.015165
#  - MAE:  0.089249
#  - RSE:  0.642613
#  - Corr: 0.767015
#
# === Dataset: traffic ===
# Original data shape: (17544, 862)
# Created sequences -> X: torch.Size([17352, 96, 862]), y: torch.Size([17352, 96, 862])
# Train size: 500, Test size: 100
#
# --- Training model: LinearModel ---
#
# --- Training LinearModel ---
# Input shape: torch.Size([500, 96, 862]), Target shape: torch.Size([500, 96, 862])
# Device: cpu
# Epoch 1/10 | Loss: 0.2632
# Epoch 2/10 | Loss: 0.1486
# Epoch 3/10 | Loss: 0.1134
# Epoch 4/10 | Loss: 0.1008
# Epoch 5/10 | Loss: 0.0919
# Epoch 6/10 | Loss: 0.0854
# Epoch 7/10 | Loss: 0.0807
# Epoch 8/10 | Loss: 0.0773
# Epoch 9/10 | Loss: 0.0750
# Epoch 10/10 | Loss: 0.0728
# Training complete for LinearModel ✅
#
# Finished training LinearModel, now evaluating...
#
# --- Evaluating LinearModel ---
# X_test shape: torch.Size([100, 96, 862]), y_test shape: torch.Size([100, 96, 862])
# Prediction shape: (100, 96, 862), Ground truth shape: (100, 96, 862)
#
# First 5 predictions vs. true values (flattened):
# Pred: [0.12696178 0.05235502 0.19560182 0.10072902 0.01745292] | True: [0.067411   0.06266667 0.13068317 0.09116636 0.02482182]
# Pred: [0.02257205 0.04254166 0.16299365 0.0863234  0.01267533] | True: [0.05940594 0.05733333 0.11283028 0.08712351 0.02482182]
# Pred: [0.07001553 0.03456011 0.08020122 0.06660192 0.00621983] | True: [0.0471877  0.05177778 0.1061652  0.08954922 0.02113541]
# Pred: [ 5.9698258e-02  3.7502427e-02  1.7169678e-01  6.8493620e-02
#  -6.8478286e-05] | True: [0.01558879 0.03711111 0.07736253 0.0667071  0.01474564]
# Pred: [ 0.08937249  0.01563508  0.17511936  0.04292982 -0.01850048] | True: [0.01200758 0.02488889 0.05236848 0.04386497 0.0093389 ]
#
# Metrics:
#  - MSE:  0.005014
#  - MAE:  0.046658
#  - RSE:  0.726512
#  - Corr: 0.711288
#
# --- Training model: DLinear ---
#
# --- Training DLinear ---
# Input shape: torch.Size([500, 96, 862]), Target shape: torch.Size([500, 96, 862])
# Device: cpu
# Epoch 1/10 | Loss: 0.2131
# Epoch 2/10 | Loss: 0.1175
# Epoch 3/10 | Loss: 0.0969
# Epoch 4/10 | Loss: 0.0846
# Epoch 5/10 | Loss: 0.0749
# Epoch 6/10 | Loss: 0.0695
# Epoch 7/10 | Loss: 0.0661
# Epoch 8/10 | Loss: 0.0641
# Epoch 9/10 | Loss: 0.0625
# Epoch 10/10 | Loss: 0.0613
# Training complete for DLinear ✅
#
# Finished training DLinear, now evaluating...
#
# --- Evaluating DLinear ---
# X_test shape: torch.Size([100, 96, 862]), y_test shape: torch.Size([100, 96, 862])
# Prediction shape: (100, 96, 862), Ground truth shape: (100, 96, 862)
#
# First 5 predictions vs. true values (flattened):
# Pred: [0.04170629 0.04467132 0.16146618 0.0799397  0.02918915] | True: [0.067411   0.06266667 0.13068317 0.09116636 0.02482182]
# Pred: [0.05930308 0.03941998 0.09517737 0.06972222 0.01621526] | True: [0.05940594 0.05733333 0.11283028 0.08712351 0.02482182]
# Pred: [0.02447824 0.02140304 0.07751426 0.04691469 0.00736394] | True: [0.0471877  0.05177778 0.1061652  0.08954922 0.02113541]
# Pred: [ 0.00435714  0.01257913 -0.02305577  0.0347315   0.00223544] | True: [0.01558879 0.03711111 0.07736253 0.0667071  0.01474564]
# Pred: [-0.01365569  0.0275198  -0.00896044  0.03327601  0.0017022 ] | True: [0.01200758 0.02488889 0.05236848 0.04386497 0.0093389 ]
#
# Metrics:
#  - MSE:  0.004102
#  - MAE:  0.040830
#  - RSE:  0.657097
#  - Corr: 0.762153
#
# --- Training model: NLinear ---
#
# --- Training NLinear ---
# Input shape: torch.Size([500, 96, 862]), Target shape: torch.Size([500, 96, 862])
# Device: cpu
# Epoch 1/10 | Loss: 2.0911
# Epoch 2/10 | Loss: 1.3199
# Epoch 3/10 | Loss: 1.0305
# Epoch 4/10 | Loss: 0.8235
# Epoch 5/10 | Loss: 0.6836
# Epoch 6/10 | Loss: 0.5850
# Epoch 7/10 | Loss: 0.5097
# Epoch 8/10 | Loss: 0.4516
# Epoch 9/10 | Loss: 0.4052
# Epoch 10/10 | Loss: 0.3675
# Training complete for NLinear ✅
#
# Finished training NLinear, now evaluating...
#
# --- Evaluating NLinear ---
# X_test shape: torch.Size([100, 96, 862]), y_test shape: torch.Size([100, 96, 862])
# Prediction shape: (100, 96, 862), Ground truth shape: (100, 96, 862)
#
# First 5 predictions vs. true values (flattened):
# Pred: [ 0.22158572  0.01917136 -0.07604295  0.00909528  0.01432221] | True: [0.067411   0.06266667 0.13068317 0.09116636 0.02482182]
# Pred: [ 0.38357115  0.01301752 -0.18723558  0.04692412 -0.06894733] | True: [0.05940594 0.05733333 0.11283028 0.08712351 0.02482182]
# Pred: [-0.08803526  0.02304388 -0.15161619  0.00198765  0.06325076] | True: [0.0471877  0.05177778 0.1061652  0.08954922 0.02113541]
# Pred: [-0.27201366 -0.05005208  0.14491808  0.00525073  0.00315439] | True: [0.01558879 0.03711111 0.07736253 0.0667071  0.01474564]
# Pred: [-0.13522495  0.00084002  0.00789462  0.08301464 -0.02156065] | True: [0.01200758 0.02488889 0.05236848 0.04386497 0.0093389 ]
#
# Metrics:
#  - MSE:  0.039650
#  - MAE:  0.134421
#  - RSE:  2.042961
#  - Corr: 0.183954
#
# --- Training model: TransformerModel ---
#
# --- Training TransformerModel ---
# Input shape: torch.Size([500, 96, 862]), Target shape: torch.Size([500, 96, 862])
# Device: cpu
# Epoch 1/10 | Loss: 1.2946
# Epoch 2/10 | Loss: 0.3632
# Epoch 3/10 | Loss: 0.2595
# Epoch 4/10 | Loss: 0.2034
# Epoch 5/10 | Loss: 0.1719
# Epoch 6/10 | Loss: 0.1527
# Epoch 7/10 | Loss: 0.1395
# Epoch 8/10 | Loss: 0.1291
# Epoch 9/10 | Loss: 0.1197
# Epoch 10/10 | Loss: 0.1138
# Training complete for TransformerModel ✅
#
# Finished training TransformerModel, now evaluating...
#
# --- Evaluating TransformerModel ---
# X_test shape: torch.Size([100, 96, 862]), y_test shape: torch.Size([100, 96, 862])
# Prediction shape: (100, 96, 862), Ground truth shape: (100, 96, 862)
#
# First 5 predictions vs. true values (flattened):
# Pred: [0.11253129 0.12379447 0.1956426  0.11379723 0.02615889] | True: [0.067411   0.06266667 0.13068317 0.09116636 0.02482182]
# Pred: [0.10162337 0.10808837 0.16405211 0.10127406 0.01791494] | True: [0.05940594 0.05733333 0.11283028 0.08712351 0.02482182]
# Pred: [0.0878823  0.0934301  0.12862702 0.08277534 0.00536277] | True: [0.0471877  0.05177778 0.1061652  0.08954922 0.02113541]
# Pred: [ 0.06533606  0.07562378  0.08191141  0.06667927 -0.00877331] | True: [0.01558879 0.03711111 0.07736253 0.0667071  0.01474564]
# Pred: [ 0.0515254   0.07441115  0.04380275  0.0492508  -0.01331977] | True: [0.01200758 0.02488889 0.05236848 0.04386497 0.0093389 ]
#
# Metrics:
#  - MSE:  0.007510
#  - MAE:  0.058197
#  - RSE:  0.889132
#  - Corr: 0.575700
#
# --- Training model: Autoformer ---
#
# --- Training Autoformer ---
# Input shape: torch.Size([500, 96, 862]), Target shape: torch.Size([500, 96, 862])
# Device: cpu
# Epoch 1/10 | Loss: 0.2280
# Epoch 2/10 | Loss: 0.1255
# Epoch 3/10 | Loss: 0.1035
# Epoch 4/10 | Loss: 0.0930
# Epoch 5/10 | Loss: 0.0834
# Epoch 6/10 | Loss: 0.0731
# Epoch 7/10 | Loss: 0.0659
# Epoch 8/10 | Loss: 0.0613
# Epoch 9/10 | Loss: 0.0588
# Epoch 10/10 | Loss: 0.0570
# Training complete for Autoformer ✅
#
# Finished training Autoformer, now evaluating...
#
# --- Evaluating Autoformer ---
# X_test shape: torch.Size([100, 96, 862]), y_test shape: torch.Size([100, 96, 862])
# Prediction shape: (100, 96, 862), Ground truth shape: (100, 96, 862)
#
# First 5 predictions vs. true values (flattened):
# Pred: [0.01271261 0.05074734 0.21410565 0.01618128 0.00984758] | True: [0.067411   0.06266667 0.13068317 0.09116636 0.02482182]
# Pred: [-0.00245283  0.01600374  0.16457327  0.01129489  0.04005706] | True: [0.05940594 0.05733333 0.11283028 0.08712351 0.02482182]
# Pred: [0.00156437 0.00382054 0.09982961 0.04296859 0.0218491 ] | True: [0.0471877  0.05177778 0.1061652  0.08954922 0.02113541]
# Pred: [-0.04705109 -0.04248358  0.06776122 -0.00508918  0.03799115] | True: [0.01558879 0.03711111 0.07736253 0.0667071  0.01474564]
# Pred: [-0.04932614 -0.05793221  0.03077422 -0.0165419   0.03879866] | True: [0.01200758 0.02488889 0.05236848 0.04386497 0.0093389 ]
#
# Metrics:
#  - MSE:  0.008561
#  - MAE:  0.063971
#  - RSE:  0.949291
#  - Corr: 0.562566
#
# --- Training model: Informer ---
#
# --- Training Informer ---
# Input shape: torch.Size([500, 96, 862]), Target shape: torch.Size([500, 96, 862])
# Device: cpu
# Epoch 1/10 | Loss: 0.2379
# Epoch 2/10 | Loss: 0.1278
# Epoch 3/10 | Loss: 0.1024
# Epoch 4/10 | Loss: 0.0977
# Epoch 5/10 | Loss: 0.0955
# Epoch 6/10 | Loss: 0.0940
# Epoch 7/10 | Loss: 0.0920
# Epoch 8/10 | Loss: 0.0894
# Epoch 9/10 | Loss: 0.0847
# Epoch 10/10 | Loss: 0.0793
# Training complete for Informer ✅
#
# Finished training Informer, now evaluating...
#
# --- Evaluating Informer ---
# X_test shape: torch.Size([100, 96, 862]), y_test shape: torch.Size([100, 96, 862])
# Prediction shape: (100, 96, 862), Ground truth shape: (100, 96, 862)
#
# First 5 predictions vs. true values (flattened):
# Pred: [0.0980878  0.10134511 0.20786247 0.10348002 0.06509043] | True: [0.067411   0.06266667 0.13068317 0.09116636 0.02482182]
# Pred: [0.10030852 0.10292685 0.21361905 0.10576709 0.066063  ] | True: [0.05940594 0.05733333 0.11283028 0.08712351 0.02482182]
# Pred: [0.09655368 0.10018176 0.20349625 0.10176955 0.06445305] | True: [0.0471877  0.05177778 0.1061652  0.08954922 0.02113541]
# Pred: [0.09354403 0.09798896 0.19541335 0.09851514 0.06319381] | True: [0.01558879 0.03711111 0.07736253 0.0667071  0.01474564]
# Pred: [0.08985379 0.09535289 0.1856853  0.0945239  0.06166658] | True: [0.01200758 0.02488889 0.05236848 0.04386497 0.0093389 ]
#
# Metrics:
#  - MSE:  0.008804
#  - MAE:  0.067807
#  - RSE:  0.962660
#  - Corr: 0.510174
#
# --- Training model: Reformer ---
#
# --- Training Reformer ---
# Input shape: torch.Size([500, 96, 862]), Target shape: torch.Size([500, 96, 862])
# Device: cpu
# Epoch 1/10 | Loss: 0.2441
# Epoch 2/10 | Loss: 0.1488
# Epoch 3/10 | Loss: 0.1184
# Epoch 4/10 | Loss: 0.1037
# Epoch 5/10 | Loss: 0.0940
# Epoch 6/10 | Loss: 0.0875
# Epoch 7/10 | Loss: 0.0827
# Epoch 8/10 | Loss: 0.0791
# Epoch 9/10 | Loss: 0.0764
# Epoch 10/10 | Loss: 0.0740
# Training complete for Reformer ✅
#
# Finished training Reformer, now evaluating...
#
# --- Evaluating Reformer ---
# X_test shape: torch.Size([100, 96, 862]), y_test shape: torch.Size([100, 96, 862])
# Prediction shape: (100, 96, 862), Ground truth shape: (100, 96, 862)
#
# First 5 predictions vs. true values (flattened):
# Pred: [ 0.00859512  0.02346577  0.17532337  0.05409991 -0.01946893] | True: [0.067411   0.06266667 0.13068317 0.09116636 0.02482182]
# Pred: [ 0.03024616  0.02987684  0.18803784  0.06655638 -0.01322869] | True: [0.05940594 0.05733333 0.11283028 0.08712351 0.02482182]
# Pred: [ 0.02943862  0.01902627  0.19330907  0.0572508  -0.0105069 ] | True: [0.0471877  0.05177778 0.1061652  0.08954922 0.02113541]
# Pred: [-0.01430343  0.00721155  0.18160616  0.04432868  0.00152427] | True: [0.01558879 0.03711111 0.07736253 0.0667071  0.01474564]
# Pred: [ 0.03551417  0.00738233  0.10806389  0.0331306  -0.00435089] | True: [0.01200758 0.02488889 0.05236848 0.04386497 0.0093389 ]
#
# Metrics:
#  - MSE:  0.005114
#  - MAE:  0.047110
#  - RSE:  0.733724
#  - Corr: 0.703682
#
# --- Training model: FEDformer ---
#
# --- Training FEDformer ---
# Input shape: torch.Size([500, 96, 862]), Target shape: torch.Size([500, 96, 862])
# Device: cpu
# Epoch 1/10 | Loss: 0.2053
# Epoch 2/10 | Loss: 0.1116
# Epoch 3/10 | Loss: 0.0901
# Epoch 4/10 | Loss: 0.0790
# Epoch 5/10 | Loss: 0.0715
# Epoch 6/10 | Loss: 0.0673
# Epoch 7/10 | Loss: 0.0646
# Epoch 8/10 | Loss: 0.0630
# Epoch 9/10 | Loss: 0.0617
# Epoch 10/10 | Loss: 0.0604
# Training complete for FEDformer ✅
#
# Finished training FEDformer, now evaluating...
#
# --- Evaluating FEDformer ---
# X_test shape: torch.Size([100, 96, 862]), y_test shape: torch.Size([100, 96, 862])
# Prediction shape: (100, 96, 862), Ground truth shape: (100, 96, 862)
#
# First 5 predictions vs. true values (flattened):
# Pred: [0.08347922 0.03718278 0.10074161 0.07128628 0.02592334] | True: [0.067411   0.06266667 0.13068317 0.09116636 0.02482182]
# Pred: [0.01161666 0.02912702 0.06241988 0.05634824 0.01287833] | True: [0.05940594 0.05733333 0.11283028 0.08712351 0.02482182]
# Pred: [0.01718337 0.03230424 0.00559532 0.05142218 0.01657743] | True: [0.0471877  0.05177778 0.1061652  0.08954922 0.02113541]
# Pred: [0.05444426 0.0318177  0.02429525 0.04746117 0.01173292] | True: [0.01558879 0.03711111 0.07736253 0.0667071  0.01474564]
# Pred: [0.00811739 0.02111911 0.06218992 0.03493278 0.01486829] | True: [0.01200758 0.02488889 0.05236848 0.04386497 0.0093389 ]
#
# Metrics:
#  - MSE:  0.004009
#  - MAE:  0.039835
#  - RSE:  0.649650
#  - Corr: 0.767734
#
# === Dataset: exchange_rate ===
# Original data shape: (7588, 8)
# Created sequences -> X: torch.Size([7396, 96, 8]), y: torch.Size([7396, 96, 8])
# Train size: 500, Test size: 100
#
# --- Training model: LinearModel ---
#
# --- Training LinearModel ---
# Input shape: torch.Size([500, 96, 8]), Target shape: torch.Size([500, 96, 8])
# Device: cpu
# Epoch 1/10 | Loss: 1.5446
# Epoch 2/10 | Loss: 0.4005
# Epoch 3/10 | Loss: 0.1451
# Epoch 4/10 | Loss: 0.1020
# Epoch 5/10 | Loss: 0.0822
# Epoch 6/10 | Loss: 0.0677
# Epoch 7/10 | Loss: 0.0608
# Epoch 8/10 | Loss: 0.0570
# Epoch 9/10 | Loss: 0.0550
# Epoch 10/10 | Loss: 0.0539
# Training complete for LinearModel ✅
#
# Finished training LinearModel, now evaluating...
#
# --- Evaluating LinearModel ---
# X_test shape: torch.Size([100, 96, 8]), y_test shape: torch.Size([100, 96, 8])
# Prediction shape: (100, 96, 8), Ground truth shape: (100, 96, 8)
#
# First 5 predictions vs. true values (flattened):
# Pred: [0.43027177 0.25706655 0.32457823 0.5752067  0.34413776] | True: [0.41392905 0.2498323  0.33197728 0.59765685 0.33024514]
# Pred: [0.43383202 0.25929222 0.3259246  0.5764958  0.3454297 ] | True: [0.42368132 0.28414446 0.3417586  0.5950704  0.33227372]
# Pred: [0.4315001  0.25678512 0.32216597 0.5718597  0.34347594] | True: [0.42507336 0.2849122  0.3430463  0.59630364 0.32990316]
# Pred: [0.42321685 0.25593242 0.31527817 0.57106537 0.3430625 ] | True: [0.429545   0.28207418 0.33937988 0.5985521  0.332196  ]
# Pred: [0.43465143 0.26471776 0.32522777 0.57134306 0.34241298] | True: [0.44627517 0.3021474  0.3468586  0.5997708  0.33223486]
#
# Metrics:
#  - MSE:  0.004032
#  - MAE:  0.045638
#  - RSE:  0.329555
#  - Corr: 0.955550
#
# --- Training model: DLinear ---
#
# --- Training DLinear ---
# Input shape: torch.Size([500, 96, 8]), Target shape: torch.Size([500, 96, 8])
# Device: cpu
# Epoch 1/10 | Loss: 1.0190
# Epoch 2/10 | Loss: 0.1977
# Epoch 3/10 | Loss: 0.1053
# Epoch 4/10 | Loss: 0.0804
# Epoch 5/10 | Loss: 0.0626
# Epoch 6/10 | Loss: 0.0559
# Epoch 7/10 | Loss: 0.0523
# Epoch 8/10 | Loss: 0.0496
# Epoch 9/10 | Loss: 0.0480
# Epoch 10/10 | Loss: 0.0464
# Training complete for DLinear ✅
#
# Finished training DLinear, now evaluating...
#
# --- Evaluating DLinear ---
# X_test shape: torch.Size([100, 96, 8]), y_test shape: torch.Size([100, 96, 8])
# Prediction shape: (100, 96, 8), Ground truth shape: (100, 96, 8)
#
# First 5 predictions vs. true values (flattened):
# Pred: [0.42544806 0.27832043 0.33572254 0.5814743  0.36068088] | True: [0.41392905 0.2498323  0.33197728 0.59765685 0.33024514]
# Pred: [0.42382136 0.27657074 0.3335698  0.58244306 0.36049426] | True: [0.42368132 0.28414446 0.3417586  0.5950704  0.33227372]
# Pred: [0.42794484 0.28299025 0.3408599  0.5833046  0.36062866] | True: [0.42507336 0.2849122  0.3430463  0.59630364 0.32990316]
# Pred: [0.42600024 0.2812826  0.33848634 0.5833302  0.36042747] | True: [0.429545   0.28207418 0.33937988 0.5985521  0.332196  ]
# Pred: [0.4284835  0.2777095  0.33665746 0.58279383 0.3601802 ] | True: [0.44627517 0.3021474  0.3468586  0.5997708  0.33223486]
#
# Metrics:
#  - MSE:  0.004198
#  - MAE:  0.046310
#  - RSE:  0.336258
#  - Corr: 0.961264
#
# --- Training model: NLinear ---
#
# --- Training NLinear ---
# Input shape: torch.Size([500, 96, 8]), Target shape: torch.Size([500, 96, 8])
# Device: cpu
# Epoch 1/10 | Loss: 3.2933
# Epoch 2/10 | Loss: 1.6539
# Epoch 3/10 | Loss: 1.4095
# Epoch 4/10 | Loss: 1.3066
# Epoch 5/10 | Loss: 1.2075
# Epoch 6/10 | Loss: 1.1294
# Epoch 7/10 | Loss: 1.0640
# Epoch 8/10 | Loss: 1.0081
# Epoch 9/10 | Loss: 0.9539
# Epoch 10/10 | Loss: 0.9024
# Training complete for NLinear ✅
#
# Finished training NLinear, now evaluating...
#
# --- Evaluating NLinear ---
# X_test shape: torch.Size([100, 96, 8]), y_test shape: torch.Size([100, 96, 8])
# Prediction shape: (100, 96, 8), Ground truth shape: (100, 96, 8)
#
# First 5 predictions vs. true values (flattened):
# Pred: [ 0.03975628 -0.1581083  -0.1434789   0.29661554 -0.05915377] | True: [0.41392905 0.2498323  0.33197728 0.59765685 0.33024514]
# Pred: [ 0.05167103 -0.151124   -0.13532156  0.28266066 -0.04413516] | True: [0.42368132 0.28414446 0.3417586  0.5950704  0.33227372]
# Pred: [ 0.07972956 -0.14431933 -0.12347127  0.2795274  -0.06552853] | True: [0.42507336 0.2849122  0.3430463  0.59630364 0.32990316]
# Pred: [ 0.07283334 -0.13763317 -0.09548175  0.2764079  -0.08662838] | True: [0.429545   0.28207418 0.33937988 0.5985521  0.332196  ]
# Pred: [ 0.06754413 -0.13898149 -0.10861517  0.2946775  -0.06946144] | True: [0.44627517 0.3021474  0.3468586  0.5997708  0.33223486]
#
# Metrics:
#  - MSE:  0.139411
#  - MAE:  0.361338
#  - RSE:  1.937860
#  - Corr: 0.909769
#
# --- Training model: TransformerModel ---
#
# --- Training TransformerModel ---
# Input shape: torch.Size([500, 96, 8]), Target shape: torch.Size([500, 96, 8])
# Device: cpu
# Epoch 1/10 | Loss: 16.2513
# Epoch 2/10 | Loss: 0.6526
# Epoch 3/10 | Loss: 0.3306
# Epoch 4/10 | Loss: 0.2682
# Epoch 5/10 | Loss: 0.2486
# Epoch 6/10 | Loss: 0.2361
# Epoch 7/10 | Loss: 0.2291
# Epoch 8/10 | Loss: 0.2224
# Epoch 9/10 | Loss: 0.2174
# Epoch 10/10 | Loss: 0.2112
# Training complete for TransformerModel ✅
#
# Finished training TransformerModel, now evaluating...
#
# --- Evaluating TransformerModel ---
# X_test shape: torch.Size([100, 96, 8]), y_test shape: torch.Size([100, 96, 8])
# Prediction shape: (100, 96, 8), Ground truth shape: (100, 96, 8)
#
# First 5 predictions vs. true values (flattened):
# Pred: [0.49301618 0.6723039  0.54287654 0.19964974 0.64737254] | True: [0.41392905 0.2498323  0.33197728 0.59765685 0.33024514]
# Pred: [0.4930294  0.6722986  0.54287773 0.1996464  0.6473679 ] | True: [0.42368132 0.28414446 0.3417586  0.5950704  0.33227372]
# Pred: [0.49294788 0.67241424 0.54280823 0.19964461 0.6473849 ] | True: [0.42507336 0.2849122  0.3430463  0.59630364 0.32990316]
# Pred: [0.49295896 0.67241    0.5428144  0.19964401 0.6473878 ] | True: [0.429545   0.28207418 0.33937988 0.5985521  0.332196  ]
# Pred: [0.4929625  0.6724086  0.54281574 0.1996437  0.64738876] | True: [0.44627517 0.3021474  0.3468586  0.5997708  0.33223486]
#
# Metrics:
#  - MSE:  0.129733
#  - MAE:  0.327501
#  - RSE:  1.869382
#  - Corr: -0.792081
#
# --- Training model: Autoformer ---
#
# --- Training Autoformer ---
# Input shape: torch.Size([500, 96, 8]), Target shape: torch.Size([500, 96, 8])
# Device: cpu
# Epoch 1/10 | Loss: 1.5849
# Epoch 2/10 | Loss: 1.1335
# Epoch 3/10 | Loss: 0.8018
# Epoch 4/10 | Loss: 0.5416
# Epoch 5/10 | Loss: 0.3597
# Epoch 6/10 | Loss: 0.2376
# Epoch 7/10 | Loss: 0.1594
# Epoch 8/10 | Loss: 0.1116
# Epoch 9/10 | Loss: 0.0829
# Epoch 10/10 | Loss: 0.0663
# Training complete for Autoformer ✅
#
# Finished training Autoformer, now evaluating...
#
# --- Evaluating Autoformer ---
# X_test shape: torch.Size([100, 96, 8]), y_test shape: torch.Size([100, 96, 8])
# Prediction shape: (100, 96, 8), Ground truth shape: (100, 96, 8)
#
# First 5 predictions vs. true values (flattened):
# Pred: [0.7621726  0.39327505 0.30172035 0.08886156 1.0333252 ] | True: [0.41392905 0.2498323  0.33197728 0.59765685 0.33024514]
# Pred: [0.76765084 0.39463246 0.3008732  0.09018105 1.0373844 ] | True: [0.42368132 0.28414446 0.3417586  0.5950704  0.33227372]
# Pred: [0.76596975 0.3950755  0.29880244 0.08859217 1.037413  ] | True: [0.42507336 0.2849122  0.3430463  0.59630364 0.32990316]
# Pred: [0.7621031  0.3953859  0.29820257 0.08937865 1.0327278 ] | True: [0.429545   0.28207418 0.33937988 0.5985521  0.332196  ]
# Pred: [0.7567141  0.39440984 0.2974225  0.08751468 1.0272878 ] | True: [0.44627517 0.3021474  0.3468586  0.5997708  0.33223486]
#
# Metrics:
#  - MSE:  0.141360
#  - MAE:  0.301153
#  - RSE:  1.951354
#  - Corr: -0.119046
#
# --- Training model: Informer ---
#
# --- Training Informer ---
# Input shape: torch.Size([500, 96, 8]), Target shape: torch.Size([500, 96, 8])
# Device: cpu
# Epoch 1/10 | Loss: 1.5308
# Epoch 2/10 | Loss: 1.2108
# Epoch 3/10 | Loss: 0.7117
# Epoch 4/10 | Loss: 0.2919
# Epoch 5/10 | Loss: 0.1337
# Epoch 6/10 | Loss: 0.0676
# Epoch 7/10 | Loss: 0.0540
# Epoch 8/10 | Loss: 0.0455
# Epoch 9/10 | Loss: 0.0415
# Epoch 10/10 | Loss: 0.0398
# Training complete for Informer ✅
#
# Finished training Informer, now evaluating...
#
# --- Evaluating Informer ---
# X_test shape: torch.Size([100, 96, 8]), y_test shape: torch.Size([100, 96, 8])
# Prediction shape: (100, 96, 8), Ground truth shape: (100, 96, 8)
#
# First 5 predictions vs. true values (flattened):
# Pred: [0.5924964  0.5232966  0.48259965 0.12138727 0.7201853 ] | True: [0.41392905 0.2498323  0.33197728 0.59765685 0.33024514]
# Pred: [0.5925473  0.52277094 0.4826688  0.12110133 0.72057706] | True: [0.42368132 0.28414446 0.3417586  0.5950704  0.33227372]
# Pred: [0.59259784 0.52224505 0.48283798 0.12071235 0.7210735 ] | True: [0.42507336 0.2849122  0.3430463  0.59630364 0.32990316]
# Pred: [0.5926455  0.5217874  0.48277375 0.12045067 0.7210891 ] | True: [0.429545   0.28207418 0.33937988 0.5985521  0.332196  ]
# Pred: [0.59269917 0.5213603  0.4827627  0.12018492 0.7212148 ] | True: [0.44627517 0.3021474  0.3468586  0.5997708  0.33223486]
#
# Metrics:
#  - MSE:  0.097773
#  - MAE:  0.280684
#  - RSE:  1.622870
#  - Corr: -0.299899
#
# --- Training model: Reformer ---
#
# --- Training Reformer ---
# Input shape: torch.Size([500, 96, 8]), Target shape: torch.Size([500, 96, 8])
# Device: cpu
# Epoch 1/10 | Loss: 1.2605
# Epoch 2/10 | Loss: 0.3061
# Epoch 3/10 | Loss: 0.1236
# Epoch 4/10 | Loss: 0.0949
# Epoch 5/10 | Loss: 0.0810
# Epoch 6/10 | Loss: 0.0663
# Epoch 7/10 | Loss: 0.0599
# Epoch 8/10 | Loss: 0.0572
# Epoch 9/10 | Loss: 0.0555
# Epoch 10/10 | Loss: 0.0545
# Training complete for Reformer ✅
#
# Finished training Reformer, now evaluating...
#
# --- Evaluating Reformer ---
# X_test shape: torch.Size([100, 96, 8]), y_test shape: torch.Size([100, 96, 8])
# Prediction shape: (100, 96, 8), Ground truth shape: (100, 96, 8)
#
# First 5 predictions vs. true values (flattened):
# Pred: [0.40744707 0.24431995 0.31813508 0.5900128  0.31649485] | True: [0.41392905 0.2498323  0.33197728 0.59765685 0.33024514]
# Pred: [0.41133785 0.24137998 0.32009706 0.5964649  0.317329  ] | True: [0.42368132 0.28414446 0.3417586  0.5950704  0.33227372]
# Pred: [0.40384653 0.23341766 0.316715   0.595127   0.3168178 ] | True: [0.42507336 0.2849122  0.3430463  0.59630364 0.32990316]
# Pred: [0.40429285 0.22755766 0.31536594 0.59874594 0.31657398] | True: [0.429545   0.28207418 0.33937988 0.5985521  0.332196  ]
# Pred: [0.41265875 0.22354549 0.31919345 0.5986588  0.31689844] | True: [0.44627517 0.3021474  0.3468586  0.5997708  0.33223486]
#
# Metrics:
#  - MSE:  0.003887
#  - MAE:  0.045069
#  - RSE:  0.323590
#  - Corr: 0.957094
#
# --- Training model: FEDformer ---
#
# --- Training FEDformer ---
# Input shape: torch.Size([500, 96, 8]), Target shape: torch.Size([500, 96, 8])
# Device: cpu
# Epoch 1/10 | Loss: 0.9337
# Epoch 2/10 | Loss: 0.1889
# Epoch 3/10 | Loss: 0.0953
# Epoch 4/10 | Loss: 0.0770
# Epoch 5/10 | Loss: 0.0586
# Epoch 6/10 | Loss: 0.0539
# Epoch 7/10 | Loss: 0.0501
# Epoch 8/10 | Loss: 0.0477
# Epoch 9/10 | Loss: 0.0461
# Epoch 10/10 | Loss: 0.0447
# Training complete for FEDformer ✅
#
# Finished training FEDformer, now evaluating...
#
# --- Evaluating FEDformer ---
# X_test shape: torch.Size([100, 96, 8]), y_test shape: torch.Size([100, 96, 8])
# Prediction shape: (100, 96, 8), Ground truth shape: (100, 96, 8)
#
# First 5 predictions vs. true values (flattened):
# Pred: [0.41382623 0.27484217 0.3467372  0.5553512  0.34300166] | True: [0.41392905 0.2498323  0.33197728 0.59765685 0.33024514]
# Pred: [0.41260695 0.27304646 0.3427716  0.5537696  0.34267244] | True: [0.42368132 0.28414446 0.3417586  0.5950704  0.33227372]
# Pred: [0.4118673  0.27340555 0.34030244 0.5514345  0.34179413] | True: [0.42507336 0.2849122  0.3430463  0.59630364 0.32990316]
# Pred: [0.41047004 0.27626827 0.3408228  0.5534482  0.34133342] | True: [0.429545   0.28207418 0.33937988 0.5985521  0.332196  ]
# Pred: [0.41133636 0.27622122 0.34266335 0.55220896 0.34102443] | True: [0.44627517 0.3021474  0.3468586  0.5997708  0.33223486]
#
# Metrics:
#  - MSE:  0.003969
#  - MAE:  0.046701
#  - RSE:  0.326982
#  - Corr: 0.964230

# %%
# Show results
df_results = pd.DataFrame(results, columns=['Dataset', 'Model', 'MSE', 'MAE', 'RSE', 'Corr'])
df_results
# Out:
#           Dataset             Model       MSE       MAE       RSE      Corr
# 0     electricity       LinearModel  0.020631  0.107505  0.749525  0.673790
# 1     electricity           DLinear  0.015214  0.088448  0.643646  0.766965
# 2     electricity           NLinear  0.145017  0.328001  1.987171  0.497542
# 3     electricity  TransformerModel  0.035068  0.148349  0.977189  0.441792
# 4     electricity        Autoformer  0.031649  0.138839  0.928334  0.476035
# 5     electricity          Informer  0.031938  0.145906  0.932572  0.402984
# 6     electricity          Reformer  0.020012  0.105482  0.738192  0.683831
# 7     electricity         FEDformer  0.015165  0.089249  0.642613  0.767015
# 8         traffic       LinearModel  0.005014  0.046658  0.726512  0.711288
# 9         traffic           DLinear  0.004102  0.040830  0.657097  0.762153
# 10        traffic           NLinear  0.039650  0.134421  2.042961  0.183954
# 11        traffic  TransformerModel  0.007510  0.058197  0.889132  0.575700
# 12        traffic        Autoformer  0.008561  0.063971  0.949291  0.562566
# 13        traffic          Informer  0.008804  0.067807  0.962660  0.510174
# 14        traffic          Reformer  0.005114  0.047110  0.733724  0.703682
# 15        traffic         FEDformer  0.004009  0.039835  0.649650  0.767734
# 16  exchange_rate       LinearModel  0.004032  0.045638  0.329555  0.955550
# 17  exchange_rate           DLinear  0.004198  0.046310  0.336258  0.961264
# 18  exchange_rate           NLinear  0.139411  0.361338  1.937860  0.909769
# 19  exchange_rate  TransformerModel  0.129733  0.327501  1.869382 -0.792081
# 20  exchange_rate        Autoformer  0.141360  0.301153  1.951354 -0.119046
# 21  exchange_rate          Informer  0.097773  0.280684  1.622870 -0.299899
# 22  exchange_rate          Reformer  0.003887  0.045069  0.323590  0.957094
# 23  exchange_rate         FEDformer  0.003969  0.046701  0.326982  0.964230
